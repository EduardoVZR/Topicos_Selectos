# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
# tamaño de los datos ( simulando datos ejemplo)
m = 100
x = np.random.rand(m, 1)*10 # Valores de X entre 0 y 10
y = 5*x**2+np.random.randn(m, 1)*50 # Y es una función cuadratic de x con ruido

#Grado del polinomio de aproximación
gardo = 4

# inicializar Xa con una columna de unos para el termino de intercepción
Xa= np.ones((m,1))

#crear el modelo de 1 hasta el grado de polinomio
j=[]

#Configuración de la figura para la gráfica
plt.figure(figsize=(10, 8))

# %%
for i in ranfe(1, grado+1):
    # añadir 




     # Graficar X, Yg_mc y X, Y
    plt.subplot(grado, 1, i)
    plt.plot(X, Yg_mc, "o", label='Predicted - Degree ' + str(i))
    plt.plot(X, Y, "+", label='Actual Data')
    plt.legend()
